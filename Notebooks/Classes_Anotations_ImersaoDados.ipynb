# %% [markdown]
# <a href="https://colab.research.google.com/github/cfernando89/imersao-dados-desafio-final/blob/main/Notebooks/Classes_Anotations_ImersaoDados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1

# %%
import pandas as pd

url_dados = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"

dados = pd.read_csv(url_dados, compression='zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# Que tipo de dados estou trabalhando?
# - Verificar os dados, colunas e como as informações são apresentadas

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape
# Out:
# (23814, 877)

# %%
dados['tratamento'] #pega apenas uma série dos dados
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique() #grupos de estudo
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique() #tempo em horas
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['droga'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# b01cf573a       1
# c7e535136       1
# 861a693e3       1
# b3f24a171       1
# ef4e67d99       1
# Name: droga, Length: 3289, dtype: int64

# %%
# Desafio 03: Proporção das classes tratamento.

dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize=True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %%
# Qual grupo de tempo possui mais valores? Pelo gráfico de pizza não é possível avaliar
dados['tempo'].value_counts(normalize=True)
# Out:
# 48    0.346435
# 72    0.327202
# 24    0.326363
# Name: tempo, dtype: float64

# %%
dados['tempo'].value_counts().plot.bar()

# %% [markdown]
# Quais elementos de g-0 possuem valor maior do que 0?

# %%
dados_filtrados = dados[dados['g-0'] > 0] #criação de uma máscara (filtro)
dados_filtrados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %% [markdown]
# ### Desafio 01: Investigar pq a classe tratamento é tão desbalanceada?
#
# ### Desafio 02: Plotar as 5 últimas linhas da tabela (dados.tail(5))
#
# ### Desafio 03: Proporção das classes tratamento. (pesquisar "value_counts" na documentação do Pandas)
#
# ### Desafio 04: Quantos tipos de drogas foram investigados? len(dados['droga'].unique()
#
# ### Desafio 05: Procurar na documentação do Pandas o método 'query'
#
# ### Desafio 06: Renomear as colunas tirando o hífen (pode dar problema ao usar o query) - g0, g1, g2, etc
#
# ### Desafio 07: Deixar os gráficos bonitões - Colocar título, legenda etc nos gráficos (matplotlib.pyplot)
#
# ### Desafio 08: Resumo do que você aprendeu com os dados (exploração, tamanho, tipos e categorias pra cada coluna, frequÊncia e proporções, gráficos, queries

# %% [markdown]
# # Aula 2

# %%
import seaborn as sns

# %%
mapa = {'droga':'composto'}
dados.rename(columns=mapa,inplace=True)
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[:5]
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
sns.set() #traz as formatações padrões do sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8)) #alteração do tamanho da figura

ax = sns.countplot(x = 'composto',data=dados.query('composto in @cod_compostos')) # o mais comum é colocar o gráfico em si dentro de uma variável, e inserir as mudanças na variável
ax.set_title('Top 5 Compostos')
plt.show() #Função "print" para o gráfico - retorna apenas a figura, sem dados da variável

# %%
dados['g-0'].hist(bins=50)

# %%
dados['g-19'].hist(bins=50)

# %%
dados.describe()[['g-0','g-1']]
# Out:
#                 g-0           g-1
# count  23814.000000  23814.000000
# mean       0.248366     -0.095684
# std        1.393399      0.812363
# min       -5.513000     -5.737000
# 25%       -0.473075     -0.562200
# 50%       -0.008850     -0.046600
# 75%        0.525700      0.403075
# max       10.000000      5.039000

# %%
dados.loc[0:,'g-0':'g-771'].describe()
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %%
dados.loc[0:,'g-0':'g-771'].describe().T['mean'].hist(bins=30) # '.T' = transpose

# %%
dados.loc[0:,'g-0':'g-771'].describe().T['min'].hist(bins=30)

# %%
dados.loc[0:,'g-0':'g-771'].describe().T['max'].hist(bins=30)

# %%
dados.loc[0:,'c-0':].describe().T['mean'].hist(bins=30)

# %%
sns.boxplot(x='g-0', data = dados)

# %%
plt.figure(figsize=(10, 8)) #alteração do tamanho da figura #Colocar antes de chamar a figura
sns.boxplot(y='g-0', x='tratamento', data = dados)

# %% [markdown]
# ### Desafio 01: Ordenar o gráfico countplot
# #### Desafio 1.1: Colocar dois gráficos lado a lado
# ### Desafio 02: Melhorar a visualização alterando tamanho da fonte
# ### Desafio 03: Plotar os histogramas com seaborn
# ### Desafio 04: Estudar sobre as estatísticas retornadas no .describe()
# ### Desafio 05: Refletir sobre a manipulação do tamanho das visualizações
# ### Desafio 06: Fazer outras análises com boxplot e histograma
# ### Desafio 07: Resumo do que você aprendeu com os dados

# %% [markdown]
# # Aula 3

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
# Criando uma tabela de frequencia para analisar proporções das variáveis categóricas
#pandas.crosstab

pd.crosstab(dados['dose'],dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'],normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
# Tabela frequencia para Médias (aggfunc='mean') ou Mediana (aggfunc='median'), para cada condição, para g-0
pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'], values=dados['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
# Analisar o que acontece com a variação de variáveis contínuas (ex.: g-0 e g-3) (grafico de dispersão)

plt.figure(figsize=[10,8])
sns.scatterplot(x='g-0', y='g-3',data=dados)

# %%
plt.figure(figsize=[10,8])
sns.scatterplot(x='g-0', y='g-8',data=dados)

# %%
sns.lmplot(x='g-0', y='g-8',data=dados, line_kws={'color':'red'})

# %%
sns.lmplot(x='g-0', y='g-8',data=dados, row = 'tratamento',col='tempo',line_kws={'color':'red'})

# %%
# Correlação

dados.loc[:,'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
# Matrix de correlação Heatmap
import numpy as np

# Compute the correlation matrix
corr = dados.loc[:,'g-0':'g-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Compute the correlation matrix
corr_celular = dados.loc[:,'g-750':'c-25'].corr()

# %%
# Matrix de correlação Heatmap


# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ### Desafio 01: construir a tabela de frequencia utilizando pandas.groupby()
# ### Desafio 02: Normalizar crosstab pela coluna
#
# ```
# pd.crosstab([dados['dose'],dados['tempo']],dados['tratamento'],normalize='columns')
# ```
#
# ### Desafio 03: Explorar outros agregadores (ex.: mediana)
# ### Desafio 04: Explorar pandas.melt()
# ### Desafio 05: Calcular e analisar a correlação entre G e C
#   # Refletir pq algumas expressões gênicas afetam várias (ou todas as) células
# ### Desafio 06: Estudar o código que plota a matriz de correlação (heatmap)
# ### Desafio 07: Resumo do que vc aprendeu com os dados

# %% [markdown]
# #Aula 4

# %%
import pandas as pd
dados_resultado = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/imersaodados3/main/dados/dados_resultados.csv')
dados_resultado.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %%
dados_resultado['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
dados_resultado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23814 entries, 0 to 23813
# Columns: 207 entries, id to wnt_inhibitor
# dtypes: int64(206), object(1)
# memory usage: 37.6+ MB

# %%
## Soma por coluna
contagem_moa = dados_resultado.select_dtypes('int64').sum().sort_values(ascending=False) #seleciona colunas do DF baseado no tipo delas
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
## Soma por linhas
dados_resultado.drop('id',axis=1).sum(axis=1).value_counts()

#Dos valores com '0' de ativação, são todos controles? Tem algum controle que não está com ativação '0'?
# Out:
# 1    12532
# 0     9367
# 2     1538
# 3      303
# 4       55
# 5       13
# 7        6
# dtype: int64

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados_resultado['n_moa']= dados_resultado.drop('id',axis=1).sum(axis=1)
dados_resultado['ativo_moa'] = dados_resultado['n_moa']!=0
dados_resultado.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0  id_000644bb2                            0  ...      1       True
# 1  id_000779bfc                            0  ...      0      False
# 2  id_000a6266a                            0  ...      3       True
# 3  id_0015fd391                            0  ...      0      False
# 4  id_001626bd3                            0  ...      1       True
#
# [5 rows x 209 columns]

# %%
#JUNTAR AS DUAS BASES
dados_combinados = pd.merge(dados, dados_resultado[['id','n_moa','ativo_moa']],on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados[['tratamento','ativo_moa']].value_counts()
# Out:
# tratamento    ativo_moa
# com_droga     True         14447
#               False         7501
# com_controle  False         1866
# dtype: int64

# %%
dados_combinados['composto'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# b01cf573a       1
# c7e535136       1
# 861a693e3       1
# b3f24a171       1
# ef4e67d99       1
# Name: composto, Length: 3289, dtype: int64

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=[12,8])
sns.boxplot(data=dados_combinados.query('composto in @composto_principal'), y='g-0', x='composto',hue='ativo_moa')

# %% [markdown]
# ### Desafio 01: Encontrar o top-10 das ações (sulfixo da coluna - inibidor, antagonista, ativador etc) - Qual ação é mais usada
#
# ### Desafio 02: Criar coluna "eh_controle" com '0' ou '1' para tipo de tratamento
#
# ### Desafio 03: Transformar coluna de 'tempo' para binário (tres colunas)
#
# ### Desafio 04: Estudar sobre combinações de dataframe
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#
# ### Desafio 05: Fazer análise mais detalhada considerando tempo e dose, para comparar as distrivuições
#
# ### Desafio 06: Descobrir se tem algum composto que, dependendo da configuração do experimento (tempo, dose etc), ativa ou não ativa algum MOA (ou um MOA diferente)
#
# ### Desafio 07: Descobrir se tem algum composto que, dependendo da configuração do experimento (tempo, dose etc), ativa ou MOAs diferentes
#
# ### Desafio 08: Resumo do que vc aprendeu com os dados

# %% [markdown]
# #Aula 5
